# %%
halitName = "Halit"

# %%
halitAge = 23

# %%
halitGender = "Male"

# %%
atlasName = "Atlas"

# %%
atlasAge = 10

# %%
atlasGender = "Male"

# %%
class Person():
    #name = ""
    #age = 0
    #gender = ""
    job = ""
    
    #initializer method
    def __init__(self,name,age,gender):
        self.name = name
        self.age = age
        self.gender = gender
    #method
    def printName(self):
        print(self.name)

# %%
myList = list()

# %%
type(myList)
# Out:
# list

# %%
halit = Person("Halit","23","Male")

# %%
type(halit)
# Out:
# __main__.Person

# %%
halit.age
# Out:
# '23'

# %%
halit.gender
# Out:
# 'Male'

# %%
halit.printName()
# Out:
# Halit

# %%
halit.job = "Developer"

# %%
halit.job
# Out:
# 'Developer'

# %%
class Dog():
    year = 7
    def __init__(self,age):
        self.age = age
        self.dogHumanAge = age * self.year
    def humanAge(self):
        return self.age * Dog.year

# %%
myDog = Dog(3)

# %%
myDog.age
# Out:
# 3

# %%
myDog.humanAge()
# Out:
# 21

# %%
myDog.dogHumanAge
# Out:
# 21
