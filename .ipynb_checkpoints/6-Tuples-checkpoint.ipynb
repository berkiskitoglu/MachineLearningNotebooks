# %%
myList = [10,"a","b",3.14]

# %%
myList[0]
# Out:
# 10

# %%
myList[0] = 100

# %%
myList
# Out:
# [100, 'a', 'b', 3.14]

# %% [markdown]
# # Tuple

# %%
myTuple = (10,"a","b",3.14)

# %%
type(myTuple)
# Out:
# tuple

# %%
# immutability

# %%
myTuple
# Out:
# (10, 'a', 'b', 3.14)

# %%
myTuple.index("a")
# Out:
# 1

# %%
myTuple.count("a")
# Out:
# 1
