# %%
myString = "hello python"

# %%
myString.split()
# Out:
# ['hello', 'python']

# %%
type(myString.split())
# Out:
# list

# %%
# list

# %%
myString
# Out:
# 'hello python'

# %%
myString[0]
# Out:
# 'h'

# %%
# myString[0] = "a"

# %%
# immutable - imtuability

# %%
mySting = "halit"

# %% [markdown]
# # List

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
x = 10
y = 20
z = 30

# %%
myList = [x,y,z]

# %%
myList
# Out:
# [10, 20, 30]

# %%
myList = [10,20,30,50,60,70]

# %%
myList[0]
# Out:
# 10

# %%
type(myList)
# Out:
# list

# %%
type(myList[0])
# Out:
# int

# %%
myList[0]
# Out:
# 10

# %%
myList[0] = 100

# %%
# mutable , mutability

# %%
myList[0]
# Out:
# 100

# %%
len(myList)
# Out:
# 6

# %%
myList[len(myList) - 1]
# Out:
# 70

# %%
myList[-1]
# Out:
# 70

# %%
myList.append(80)

# %%
myList
# Out:
# [100, 20, 30, 50, 60, 70, 80]

# %%
myList.append(1)

# %%
myList
# Out:
# [100, 20, 30, 50, 60, 70, 80, 1]

# %%
myList.count(20)
# Out:
# 1

# %%
myList.count(24)
# Out:
# 0

# %%
myList.index(30)
# Out:
# 2

# %%
help(myList.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %%
myList
# Out:
# [100, 20, 30, 50, 60, 70, 80, 1]

# %%
myList.insert(2,35)

# %%
myList
# Out:
# [100, 20, 35, 30, 50, 60, 70, 80, 1]

# %%
myList.pop()
# Out:
# 1

# %%
myList
# Out:
# [100, 20, 35, 30, 50, 60, 70, 80]

# %%
myList.remove(20)

# %%
myList
# Out:
# [100, 35, 30, 50, 60, 70, 80]

# %%
myList.reverse()

# %%
myList
# Out:
# [80, 70, 60, 50, 30, 35, 100]

# %%
myList.sort()

# %%
myList
# Out:
# [30, 35, 50, 60, 70, 80, 100]

# %%
x = input("enter x")
# Out:
# enter x 10

# %%
x
# Out:
# '10'

# %%
type(x)
# Out:
# str

# %%
y = input("enter y :")
# Out:
# enter y : 20

# %%
y
# Out:
# '20'

# %%
z = input("enter z:")
# Out:
# enter z: 30

# %%
z
# Out:
# '30'

# %%
inputList = []

# %%
type(inputList)
# Out:
# list

# %%
len(inputList)
# Out:
# 0

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
inputList[1]
# Out:
# '20'

# %%
inputList[1] * 2
# Out:
# '2020'

# %%
type(inputList[1])
# Out:
# str

# %%
myInteger = 50

# %%
str(myInteger)
# Out:
# '50'

# %%
myString = "40"

# %%
int(myString)
# Out:
# 40

# %%
float(myString)
# Out:
# 40.0

# %%
myString = "python"

# %%
# int(myString)
# float(myString)

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
int(inputList[1]) * 2
# Out:
# 40

# %%
str(inputList)
# Out:
# "['10', '20', '30']"

# %%
inputList
# Out:
# ['10', '20', '30']

# %%
nameList = ["atil","berk","a","b"]

# %%
type(nameList)
# Out:
# list

# %%
floatList = [3.14,2.5,10.2]

# %%
type(floatList)
# Out:
# list

# %%
mixedList = ["atil",100,3.14]

# %%
type(mixedList)
# Out:
# list

# %%
list1 = [10,20,30]
list2 = [40,50,60]

# %%
list1 + list2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1 * 2
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
mixedList
# Out:
# ['atil', 100, 3.14]

# %%
type(mixedList[1])
# Out:
# int

# %%
type(mixedList[0])
# Out:
# str

# %%
# nestedList

# %%
myNestedList = [10,20,3.14,"berk",[1,2,3]]

# %%
myNestedList[0]
# Out:
# 10

# %%
myNestedList[1]
# Out:
# 20

# %%
myNestedList[2]
# Out:
# 3.14

# %%
myNestedList[3]
# Out:
# 'berk'

# %%
myNestedList[4]
# Out:
# [1, 2, 3]

# %%
x = myNestedList[0]

# %%
x
# Out:
# 10

# %%
smallList = myNestedList[4]

# %%
type(smallList)
# Out:
# list

# %%
myNestedList
# Out:
# [10, 20, 3.14, 'berk', [1, 2, 3]]

# %%
myNestedList[4][1]
# Out:
# 2

# %%
lastList = ["a","b",["c","d","e"],"f"]

# %%
len(lastList)
# Out:
# 4

# %%
firstList = [10,20,30,40,50,60,70]

# %%
firstList[::]
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
firstList[:5:]
# Out:
# [10, 20, 30, 40, 50]

# %%
firstList[2::]
# Out:
# [30, 40, 50, 60, 70]

# %%
firstList[1:6:2]
# Out:
# [20, 40, 60]
