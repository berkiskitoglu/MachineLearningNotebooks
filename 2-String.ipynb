# %%
"hello world"
# Out:
# 'hello world'

# %%
print("hello python")
# Out:
# hello python

# %%
name = "atıl"

# %%
type(name)
# Out:
# str

# %%
'halit restaurant'
# Out:
# 'halit restaurant'

# %%
"halit restaurant"
# Out:
# 'halit restaurant'

# %%
"halit's restaurant"
# Out:
# "halit's restaurant"

# %%
name = "halit"

# %%
type(name)
# Out:
# str

# %%
name = "Halit Berk İskitoğlu"

# %%
name.capitalize()
# Out:
# 'Halit berk i̇skitoğlu'

# %%
x = 10

# %%
x = 8

# %%
name
# Out:
# 'Halit Berk İskitoğlu'

# %%
help(name.count)
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.

# %%
help(name.capitalize)
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
name.count("a")
# Out:
# 1

# %%
name.count("t")
# Out:
# 2

# %%
name.upper()
# Out:
# 'HALIT BERK İSKITOĞLU'

# %%
x = 10
y = 5

# %%
x + y
# Out:
# 15

# %%
z = x + y

# %%
z
# Out:
# 15

# %%
name
# Out:
# 'Halit Berk İskitoğlu'

# %%
nameUpper = name.upper()

# %%
nameUpper
# Out:
# 'HALIT BERK İSKITOĞLU'

# %%
print(name.upper())
# Out:
# HALIT BERK İSKITOĞLU

# %%
help(name.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
# Length
len(name)
# Out:
# 20

# %%
print("halit berk iskitoğlu")
# Out:
# halit berk iskitoğlu

# %%
# \n => new line
# escape characters
print("halit \nberk \niskitoğlu")
# Out:
# halit
# berk
# iskitoğlu

# %%
# \t => tab
print("halit \tberk iskitoğlu")
# Out:
# halit 	berk iskitoğlu

# %% [markdown]
# # Index

# %%
myString = "hello python"

# %%
myString[4]
# Out:
# 'o'

# %%
myString[0]
# Out:
# 'h'

# %%
myString[5]
# Out:
# ' '

# %%
myString = "halit berk iskitoğlu"

# %%
myString[0]
# Out:
# 'h'

# %%
len(myString)
# Out:
# 20

# %%
len(myString) - 1
# Out:
# 19

# %%
myName = "james hetfield"

# %%
myName[len(myName) - 1]
# Out:
# 'd'

# %%
myName[-1]
# Out:
# 'd'

# %%
myName[-2]
# Out:
# 'l'

# %%
barcode = "ADEG12315314"

# %%
barcode[0]
# Out:
# 'A'

# %%
barcode[1]
# Out:
# 'D'

# %%
barcode[2]
# Out:
# 'E'

# %%
"A" + "B"
# Out:
# 'AB'

# %%
name = "halit "
surname = "berk iskitoğlu"
fullName = name + surname

# %%
fullName
# Out:
# 'halit berk iskitoğlu'

# %%
fullName * 5
# Out:
# 'halit berk iskitoğluhalit berk iskitoğluhalit berk iskitoğluhalit berk iskitoğluhalit berk iskitoğlu'

# %%
100 * "a"
# Out:
# 'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa'

# %%
barcode
# Out:
# 'ADEG12315314'

# %%
barcode[0] + barcode[1] + barcode[2]
# Out:
# 'ADE'

# %%
# slicing , starting_index , stopping_index , stepping_size

# %%
barcode[::]
# Out:
# 'ADEG12315314'

# %%
# barcode[starting_index:stopping_index:stepping_size]

# %%
barcode[3::]
# Out:
# 'G12315314'

# %%
barcode[:3:]
# Out:
# 'ADE'

# %%
barcode[::2]
# Out:
# 'AE1351'

# %%
barcode[::3]
# Out:
# 'AG33'

# %%
barcode[::]
# Out:
# 'ADEG12315314'

# %%
barcode[3::]
# Out:
# 'G12315314'

# %%
barcode[3:5:]
# Out:
# 'G1'

# %%
barcode[3:5]
# Out:
# 'G1'

# %%
barcode[::-1]
# Out:
# '41351321GEDA'

# %%
name = "halit berk iskitoğlu"

# %%
help(name.index)
# Out:
# Help on built-in function index:
#
# index(sub[, start[, end]], /) method of builtins.str instance
#     Return the lowest index in S where substring sub is found, such that sub is contained within S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.
#     Raises ValueError when the substring is not found.

# %%
name.index("h")
# Out:
# 0

# %%
name.split()
# Out:
# ['halit', 'berk', 'iskitoğlu']

# %%
type(name.split())
# Out:
# list
