# %%
age = input("enter age: ")
# Out:
# enter age:  35

# %%
age
# Out:
# '35'

# %%
int(age)
# Out:
# 35

# %%
int(age) * 2
# Out:
# 70

# %%
# try-except

# %%
while True:
    try:
        myAge = int(input("enter age: "))
        print(myAge * 2)
        break;
    except:
        print("enter your age !!!")
    else:
        print("else executed")
    finally:
        print("finally")
# Out:
# enter age:  atil
# enter your age !!!
# finally
# enter age:  25
# 50
# finally
