# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
myBollean = True

# %%
type(myBollean)
# Out:
# bool

# %%
myBollean = False

# %%
5 > 3
# Out:
# True

# %%
3 < 1
# Out:
# False

# %%
3 > 5
# Out:
# False

# %%
age = input("Age : ")
# Out:
# Age :  24

# %%
int(age) > 10
# Out:
# True
