# %%
name : str = "Halit"
afe  : int = 23
is_student : bool = False

# %%
type(name)
# Out:
# str

# %%
surname : str = 20

# %%
type(surname)
# Out:
# int

# %%
def add_numbers(a:int,b:int) -> int:
    return a + b

# %%
add_numbers(4,5)
# Out:
# 9

# %%
def process_value(value: int | str) -> str:
    if isinstance(value,int):
        return f"process integer : {value}"
    else:
        return f"process string :  {value}"

# %%
process_value(3)
# Out:
# 'process integer : 3'

# %%
process_value("sada")
# Out:
# 'process string :  sada'
