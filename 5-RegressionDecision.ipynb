# %%
# https://github.com/shankarpandala/lazypredict

# %%
# !pip install lazypredict --no-warn-script-location
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lazypredict in c:\users\iskit\appdata\roaming\python\python313\site-packages (0.3.0)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (8.2.1)
# Requirement already satisfied: scikit-learn>=1.0 in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (1.7.2)
# Requirement already satisfied: pandas>=1.3 in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (2.3.3)
# Requirement already satisfied: tqdm>=4.0 in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (4.67.1)
# Requirement already satisfied: joblib>=1.0 in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (1.5.2)
# Requirement already satisfied: numpy>=1.21 in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.3->lazypredict) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.3->lazypredict) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.3->lazypredict) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3->lazypredict) (1.17.0)
# Requirement already satisfied: scipy>=1.8.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.0->lazypredict) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.0->lazypredict) (3.5.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.0->lazypredict) (0.4.6)

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np

# %%
diabetes  = datasets.load_diabetes()

# %%
X, y = shuffle(diabetes.data, diabetes.target, random_state=13)
X = X.astype(np.float32)

offset = int(X.shape[0] * 0.9)

X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]

# %%
X[0]
# Out:
# array([-0.00551456, -0.04464164,  0.05630714, -0.03665608, -0.04835136,
#        -0.04296262, -0.07285395,  0.03799897,  0.05078203,  0.0569118 ],
#       dtype=float32)

# %%
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#                                Adjusted R-Squared  R-Squared        RMSE  \
# Model
# ExtraTreesRegressor                      0.378921   0.520076   54.220181
# OrthogonalMatchingPursuitCV              0.374947   0.517004   54.393391
# Lasso                                    0.373483   0.515873   54.457047
# LassoLars                                0.373474   0.515866   54.457447
# LarsCV                                   0.371500   0.514341   54.543151
# LassoCV                                  0.370413   0.513501   54.590300
# PassiveAggressiveRegressor               0.366958   0.510831   54.739888
# LassoLarsIC                              0.364985   0.509306   54.825138
# SGDRegressor                             0.364307   0.508783   54.854375
# Ridge                                    0.363002   0.507774   54.910662
# RidgeCV                                  0.363002   0.507774   54.910673
# BayesianRidge                            0.362297   0.507229   54.941053
# LassoLarsCV                              0.361749   0.506806   54.964636
# TransformedTargetRegressor               0.361749   0.506806   54.964649
# LinearRegression                         0.361749   0.506806   54.964649
# Lars                                     0.358828   0.504549   55.090292
# ElasticNetCV                             0.356159   0.502486   55.204826
# HuberRegressor                           0.355251   0.501785   55.243742
# RandomForestRegressor                    0.349621   0.497434   55.484423
# AdaBoostRegressor                        0.340416   0.490322   55.875662
# HistGradientBoostingRegressor            0.335632   0.486625   56.077921
# PoissonRegressor                         0.323033   0.476889   56.607187
# ElasticNet                               0.301755   0.460447   57.489920
# KNeighborsRegressor                      0.299855   0.458979   57.568054
# OrthogonalMatchingPursuit                0.292421   0.453235   57.872878
# BaggingRegressor                         0.291213   0.452301   57.922287
# GradientBoostingRegressor                0.247009   0.418143   59.701142
# TweedieRegressor                         0.244215   0.415984   59.811792
# GammaRegressor                           0.223895   0.400283   60.610504
# RANSACRegressor                          0.203535   0.384550   61.400382
# LinearSVR                                0.116707   0.317455   64.660656
# ExtraTreeRegressor                       0.002019   0.228833   68.730391
# NuSVR                                   -0.066704   0.175728   71.057466
# SVR                                     -0.096413   0.152772   72.040169
# DummyRegressor                          -0.297553  -0.002655   78.370078
# QuantileRegressor                       -0.346561  -0.040525   79.836360
# DecisionTreeRegressor                   -0.470263  -0.136112   83.422885
# GaussianProcessRegressor                -0.769174  -0.367089   91.510930
# MLPRegressor                            -1.867720  -1.215965  116.508076
# KernelRidge                             -5.038213  -3.665892  169.060406
#
#                                Time Taken
# Model
# ExtraTreesRegressor              0.184766
# OrthogonalMatchingPursuitCV      0.014153
# Lasso                            0.008461
# LassoLars                        0.007934
# LarsCV                           0.045576
# LassoCV                          0.072089
# PassiveAggressiveRegressor       0.009700
# LassoLarsIC                      0.013578
# SGDRegressor                     0.008302
# Ridge                            0.009873
# RidgeCV                          0.011058
# BayesianRidge                    0.037094
# LassoLarsCV                      0.025825
# TransformedTargetRegressor       0.009416
# LinearRegression                 0.008092
# Lars                             0.019931
# ElasticNetCV                     0.061823
# HuberRegressor                   0.025028
# RandomForestRegressor            0.314651
# AdaBoostRegressor                0.082078
# HistGradientBoostingRegressor    0.152625
# PoissonRegressor                 0.016885
# ElasticNet                       0.009449
# KNeighborsRegressor              0.018550
# OrthogonalMatchingPursuit        0.008196
# BaggingRegressor                 0.041434
# GradientBoostingRegressor        0.134179
# TweedieRegressor                 0.013689
# GammaRegressor                   2.506280
# RANSACRegressor                  0.099131
# LinearSVR                        0.008443
# ExtraTreeRegressor               0.007789
# NuSVR                            0.016564
# SVR                              0.018802
# DummyRegressor                   0.006862
# QuantileRegressor                0.067720
# DecisionTreeRegressor            0.009926
# GaussianProcessRegressor         0.029567
# MLPRegressor                     0.264961
# KernelRidge                      0.016798
