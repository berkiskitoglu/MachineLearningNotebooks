# %% [markdown]
# ## Variables

# %%
# Numbers

# %%
900 / 7
# Out:
# 128.57142857142858

# %%
10 - 100
# Out:
# -90

# %%
5 * 5 * 5 * 5
# Out:
# 625

# %%
4+2
# Out:
# 6

# %%
60 / 2
# Out:
# 30.0

# %%
60 * 5
# Out:
# 300

# %%
age = 50

# %%
age
# Out:
# 50

# %%
age * 5
# Out:
# 250

# %%
age / 2
# Out:
# 25.0

# %%
age * 3
# Out:
# 150

# %%
# Data Type

# %%
type(10)
# Out:
# int

# %%
type(10 * 3)
# Out:
# int

# %%
type(age * 5)
# Out:
# int

# %%
# int => integer

# %%
type(-1000)
# Out:
# int

# %%
x = -100

# %%
type(x)
# Out:
# int

# %%
# float => floating point

# %%
type(3.14)
# Out:
# float

# %%
pi = 3.14

# %%
pi * 2
# Out:
# 6.28

# %%
x
# Out:
# -100

# %%
x + pi
# Out:
# -96.86

# %%
x / pi
# Out:
# -31.84713375796178

# %%
x = 10

# %%
x = 20

# %%
x + 10
# Out:
# 30

# %%
myFloat = 1.34432423

# %%
type(myFloat)
# Out:
# float

# %%
# camelCase
# snake_case

# %%
40 / 4
# Out:
# 10.0

# %%
type(40 / 4)
# Out:
# float

# %%
40 / 9
# Out:
# 4.444444444444445

# %%
40 / 12
# Out:
# 3.3333333333333335

# %%
4 / 2
# Out:
# 2.0

# %%
4 / 3
# Out:
# 1.3333333333333333

# %%
4.0 / 3.0
# Out:
# 1.3333333333333333

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
4 * 2
# Out:
# 8

# %%
4 + 2
# Out:
# 6

# %%
4 - 2
# Out:
# 2

# %%
4.0 - 2
# Out:
# 2.0

# %%
4.1 - 2
# Out:
# 2.0999999999999996

# %%
4.2 - 2
# Out:
# 2.2

# %%
4.4 - 2
# Out:
# 2.4000000000000004

# %%
type(4.5 - 2)
# Out:
# float

# %%
4.2 * 3
# Out:
# 12.600000000000001

# %%
4.2 * 3.2
# Out:
# 13.440000000000001

# %%
4.2 * 3 - 10
# Out:
# 2.6000000000000014

# %%
2 - 10 * 2
# Out:
# -18

# %%
2 * 2 * 2 * 2 * 2
# Out:
# 32

# %%
2 ** 5
# Out:
# 32

# %%
2 ** 9
# Out:
# 512

# %%
# Remainder
10 % 3
# Out:
# 1
